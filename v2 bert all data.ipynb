# %%
import json
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
with open('full_format_recipes.json', 'r') as f:
  data = json.load(f)
data[0]
# Out:
# {'directions': ['1. Place the stock, lentils, celery, carrot, thyme, and salt in a medium saucepan and bring to a boil. Reduce heat to low and simmer until the lentils are tender, about 30 minutes, depending on the lentils. (If they begin to dry out, add water as needed.) Remove and discard the thyme. Drain and transfer the mixture to a bowl; let cool.',
#   '2. Fold in the tomato, apple, lemon juice, and olive oil. Season with the pepper.',
#   '3. To assemble a wrap, place 1 lavash sheet on a clean work surface. Spread some of the lentil mixture on the end nearest you, leaving a 1-inch border. Top with several slices of turkey, then some of the lettuce. Roll up the lavash, slice crosswise, and serve. If using tortillas, spread the lentils in the center, top with the turkey and lettuce, and fold up the bottom, left side, and right side before rolling away from you.'],
#  'fat': 7.0,
#  'date': '2006-09-01T04:00:00.000Z',
#  'categories': ['Sandwich',
#   'Bean',
#   'Fruit',
# ...

# %%
categories = []
for data_temp in data:
  if 'categories' in data_temp:
    for category in data_temp['categories']:
      if category not in categories:
        categories.append(category)

# %%
print(len(data))
# Out:
# 20130

# %%
include_categories = ['Vegan']
data_vegan = []
for data_temp in data:
  if 'categories' in data_temp:
    for category in data_temp['categories']:
      if category in include_categories:
        data_vegan.append(data_temp)

# %%
print(len(data_vegan))
# Out:
# 1851

# %%
categories_vegan = {}
for data_temp in data_vegan:
  if 'categories' in data_temp:
    for category in data_temp['categories']:
      if category not in categories_vegan:
        categories_vegan[category] = 1
      else:
        categories_vegan[category] += 1

# %%
categories_vegan = sorted(categories_vegan.items(), key=lambda x: x[1], reverse=True)

# %%
categories_vegan[:20]
# Out:
# [('Vegan', 1851),
#  ('Vegetarian', 1730),
#  ('Kosher', 1378),
#  ('Pescatarian', 1368),
#  ('Peanut Free', 1351),
#  ('Dairy Free', 1326),
#  ('Soy Free', 1286),
#  ('Wheat/Gluten-Free', 1223),
#  ('Tree Nut Free', 1196),
#  ('Side', 941),
#  ('Bon Appétit', 800),
#  ('No Sugar Added', 730),
#  ('Quick & Easy', 724),
#  ('Gourmet', 637),
#  ('Healthy', 588),
#  ('Summer', 474),
#  ('Sugar Conscious', 403),
#  ('Kidney Friendly', 385),
#  ('Paleo', 378),
#  ('Salad', 333)]

# %%
print(len(categories_vegan))
# Out:
# 422

# %%
df_all = pd.DataFrame(data, columns=data[0].keys())
df_all
# Out:
#                                               directions   fat  \
# 0      [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1      [Combine first 9 ingredients in heavy medium s...  23.0
# 2      [In a large heavy saucepan cook diced fennel a...   7.0
# 3      [Heat oil in heavy large skillet over medium-h...   NaN
# 4      [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
# ...                                                  ...   ...
# 20125  [Beat whites in a bowl with an electric mixer ...   2.0
# 20126  [Bring broth to simmer in saucepan.Remove from...  28.0
# 20127  [Using a sharp knife, cut a shallow X in botto...  38.0
# 20128  [Heat 2 tablespoons oil in heavy medium skille...  24.0
# 20129  [Position rack in bottom third of oven and pre...  10.0
#
#                            date  \
# 0      2006-09-01T04:00:00.000Z
# 1      2004-08-20T04:00:00.000Z
# 2      2004-08-20T04:00:00.000Z
# 3      2009-03-27T04:00:00.000Z
# 4      2004-08-20T04:00:00.000Z
# ...

# %%
df_vegan = pd.DataFrame(data_vegan, columns=data_vegan[0].keys())
df_vegan
# Out:
#                                              directions   fat  \
# 0     [Halve the potatoes, unpeeled, and cut them in...  19.0
# 1     [Cut off and discard 1 inch from stem ends of ...  10.0
# 2     [Cut peel and white pith from grapefruits and ...   1.0
# 3     [Preheat oven to 475°F. Pierce eggplants with ...   7.0
# 4     [Grind the parsley, sage, rosemary, and thyme ...  12.0
# ...                                                 ...   ...
# 1846  [In a saucepan bring vinegar and water to a bo...  11.0
# 1847  [Preheat the oven to 375°F., Have an ice bath ...  27.0
# 1848  [Makes enough spice rub for two whole chickens...   0.0
# 1849  [Bring all ingredients to a simmer, covered di...   NaN
# 1850  [Stir water, sugar and juice in saucepan over ...   0.0
#
#                           date  \
# 0     2004-08-20T04:00:00.000Z
# 1     2004-08-20T04:00:00.000Z
# 2     2004-08-20T04:00:00.000Z
# 3     2004-08-20T04:00:00.000Z
# 4     2011-06-23T04:00:00.000Z
# ...

# %%
df_all = df_all.drop('date', axis=1)
df_vegan = df_vegan.drop('date', axis=1)

# %%
convert_dict = {'directions': str,
                'fat': np.float32,
                'categories': str,
                'ingredients': str,
                'calories': np.float32,
                'protein': np.float32,
                'rating': np.float32,
                'sodium': np.float32,
                }

# %%
df_all = df_all.astype(convert_dict)
df_vegan = df_vegan.astype(convert_dict)

df_all = df_all.dropna(subset=['title'])
df_vegan = df_vegan.dropna(subset=['title'])

# %%
print(f'length all data = {len(df_all)}\n')
print(f'null all data = \n{df_all.isnull().sum()}\n')
print(f'length vegan data = {len(df_vegan)}\n')
print(f'null vegan data = \n{df_vegan.isnull().sum()}\n')
# Out:
# length all data = 20111
#
# null all data =
# directions        0
# fat            4203
# categories        0
# calories       4135
# desc           6616
# protein        4182
# rating           11
# title             0
# ingredients       0
# sodium         4137
# dtype: int64
#
# length vegan data = 1851
#
# null vegan data =
# directions       0
# fat            396
# categories       0
# calories       390
# desc           505
# protein        393
# rating           0
# title            0
# ingredients      0
# sodium         390
# dtype: int64

# %%
import pandas as pd
import re
import tensorflow_hub as hub
import tensorflow as tf
import tensorflow_text as text
from sklearn import metrics

# %% [markdown]
# # Training All Data

# %%
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1", trainable=True)

text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
encoder_inputs = preprocessor(text_input)
outputs = encoder(encoder_inputs)
embedding_model_all = tf.keras.Model(text_input, outputs['pooled_output'])
embedding_model_all.compile()

# %%
df_all['encoding'] = df_all['title'].apply(lambda x: embedding_model_all(tf.constant([x])))

# %%
df_all
# Out:
#                                               directions   fat  \
# 0      ['1. Place the stock, lentils, celery, carrot,...   7.0
# 1      ['Combine first 9 ingredients in heavy medium ...  23.0
# 2      ['In a large heavy saucepan cook diced fennel ...   7.0
# 3      ['Heat oil in heavy large skillet over medium-...   NaN
# 4      ['Preheat oven to 350°F. Lightly grease 8x8x2-...  32.0
# ...                                                  ...   ...
# 20125  ['Beat whites in a bowl with an electric mixer...   2.0
# 20126  ['Bring broth to simmer in saucepan.Remove fro...  28.0
# 20127  ['Using a sharp knife, cut a shallow X in bott...  38.0
# 20128  ['Heat 2 tablespoons oil in heavy medium skill...  24.0
# 20129  ['Position rack in bottom third of oven and pr...  10.0
#
#                                               categories  calories  \
# 0      ['Sandwich', 'Bean', 'Fruit', 'Tomato', 'turke...     426.0
# 1      ['Food Processor', 'Onion', 'Pork', 'Bake', 'B...     403.0
# ...

# %%
df_all['encoding'].iloc[1]
df_all['encoding'].shape
# Out:
# (20111,)

# %%
# preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
# encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1", trainable=True)

# def get_bert_embeddings(text, preprocessor, encoder):

#   text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
#   encoder_inputs = preprocessor(text_input)
#   outputs = encoder(encoder_inputs)
#   embedding_model = tf.keras.Model(text_input, outputs['pooled_output'])
#   sentences = tf.constant([text])
#   return embedding_model(sentences)

# df_all['encoding'] = df_all['title'].apply(lambda x: get_bert_embeddings(x, preprocessor, encoder))

# %%
df_all_trained = df_all.copy()
df_all_trained
# Out:
#                                               directions   fat  \
# 0      ['1. Place the stock, lentils, celery, carrot,...   7.0
# 1      ['Combine first 9 ingredients in heavy medium ...  23.0
# 2      ['In a large heavy saucepan cook diced fennel ...   7.0
# 3      ['Heat oil in heavy large skillet over medium-...   NaN
# 4      ['Preheat oven to 350°F. Lightly grease 8x8x2-...  32.0
# ...                                                  ...   ...
# 20125  ['Beat whites in a bowl with an electric mixer...   2.0
# 20126  ['Bring broth to simmer in saucepan.Remove fro...  28.0
# 20127  ['Using a sharp knife, cut a shallow X in bott...  38.0
# 20128  ['Heat 2 tablespoons oil in heavy medium skill...  24.0
# 20129  ['Position rack in bottom third of oven and pr...  10.0
#
#                                               categories  calories  \
# 0      ['Sandwich', 'Bean', 'Fruit', 'Tomato', 'turke...     426.0
# 1      ['Food Processor', 'Onion', 'Pork', 'Bake', 'B...     403.0
# ...

# %%
def preprocess_text(text):
  text = text.lower()
  text = re.sub('[^A-Za-z0-9]+', ' ', text)
  return text
  
# query_text = preprocess_text(sentences)
# query_encoding = get_bert_embeddings(query_text, preprocessor, encoder)

# df_all_trained['similarity_score'] = df_all_trained['encoding'].apply(lambda x: metrics.pairwise.cosine_similarity(x, query_encoding)[0][0])
# df_all_trained = df_all_trained.sort_values(by=['similarity_score'], ascending=False)
# df_all_trained

# %%
test = df_vegan[['title', 'protein', 'desc']].iloc[50]
sentences = test['title']
sentences
# Out:
# 'Spinach with Pine Nuts and Raisins '

# %%
query_text = preprocess_text(sentences)
query_encoding = embedding_model_all(tf.constant([query_text]))

df_all_trained['similarity_score'] = df_all_trained['encoding'].apply(lambda x: metrics.pairwise.cosine_similarity(x, query_encoding)[0][0])
df_all_trained = df_all_trained.sort_values(by=['similarity_score'], ascending=False)
df_all_trained[:20]
# Out:
#                                               directions    fat  \
# 678    ['Rinse the spinach well and remove the stems....   10.0
# 19030  ['Place colander over large bowl. Line colande...   11.0
# 12710  ['In extra-large skillet over medium heat, hea...   10.0
# 4650   ['1. Prepare the sauce. Combine all the ingred...   57.0
# 20091  ['Arrange chicken in single layer in large Dut...   68.0
# 3066   ['Heat olive oil in heavy large skillet over h...   69.0
# 3094   ['Whisk first 6 ingredients in medium bowl to ...   40.0
# 41     ['Preheat oven to 425°F. Whisk 2 tablespoons o...   31.0
# 1348   ['Mix salt, pepper, oregano and garlic powder ...  127.0
# 7010   ['Cook rutabagas in large pot of boiling salte...    8.0
# 3190   ['Preheat oven to 350°F. Sauté beef and sausag...   53.0
# 6458   ['Rinse spinach; drain briefly, then place in ...   47.0
# 5578   ['Puree first 5 ingredients in processor until...    NaN
# 12287  ['Combine beans with enough water to cover by ...   37.0
# ...

# %%
df_all_trained[x for x in df_all_trained['categories'] if 'Vegan' in x]

# %%
df_all_trained_vegan_only = df_all_trained.apply(lambda x: x for x in x['categories'] if 'Vegan' in x)
# Out:
# C:\Users\hufah\AppData\Local\Temp\ipykernel_39424\2861188336.py:1: FutureWarning: ['fat', 'categories', 'calories', 'desc', 'protein', 'rating', 'title', 'ingredients', 'sodium', 'encoding', 'similarity_score'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_all_trained_vegan_only = df_all_trained.apply(lambda x: x for x in df_all_trained['categories'] if 'Vegan' in x)

# %%
df_all_trained_vegan_only

# %%
embedding_model_all.save('get_bert_embeddings.h5')

# %% [markdown]
# # Training only Vegan

# %%
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1", trainable=True)

text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
encoder_inputs = preprocessor(text_input)
outputs = encoder(encoder_inputs)
embedding_model_vegan = tf.keras.Model(text_input, outputs['pooled_output'])
embedding_model_vegan.compile()

# %%
df_vegan['encoding'] = df_vegan['title'].apply(lambda x: embedding_model_vegan(tf.constant([x])))

# %%
df_vegan
# Out:
#                                              directions   fat  \
# 0     ['Halve the potatoes, unpeeled, and cut them i...  19.0
# 1     ['Cut off and discard 1 inch from stem ends of...  10.0
# 2     ['Cut peel and white pith from grapefruits and...   1.0
# 3     ['Preheat oven to 475°F. Pierce eggplants with...   7.0
# 4     ['Grind the parsley, sage, rosemary, and thyme...  12.0
# ...                                                 ...   ...
# 1846  ['In a saucepan bring vinegar and water to a b...  11.0
# 1847  ['Preheat the oven to 375°F.', 'Have an ice ba...  27.0
# 1848  ['Makes enough spice rub for two whole chicken...   0.0
# 1849  ['Bring all ingredients to a simmer, covered d...   NaN
# 1850  ['Stir water, sugar and juice in saucepan over...   0.0
#
#                                              categories  calories  \
# 0     ['Salad', 'Blender', 'Olive', 'Onion', 'Potato...     351.0
# 1     ['Garlic', 'Side', 'Sauté', 'Vegetarian', 'Qui...     107.0
# ...

# %%
test_df_vegan = df_vegan.loc[df_vegan['title'] == 'Spinach with Pine Nuts and Raisins ']
sentences = test_df_vegan['title'].iloc[0]
sentences
# Out:
# 'Spinach with Pine Nuts and Raisins '

# %%
df_vegan_trained = df_vegan.copy()

# %%
query_text = preprocess_text(sentences)
query_encoding = embedding_model_vegan(tf.constant([query_text]))

df_vegan_trained['similarity_score'] = df_vegan_trained['encoding'].apply(lambda x: metrics.pairwise.cosine_similarity(x, query_encoding)[0][0])
df_vegan_trained = df_vegan_trained.sort_values(by=['similarity_score'], ascending=False)
df_vegan_trained[:20]
# Out:
#                                              directions   fat  \
# 50    ['Rinse the spinach well and remove the stems....  10.0
# 1756  ['Place colander over large bowl. Line colande...  11.0
# 912   ['Add spinach to boiling water; cook 1 minute....   NaN
# 522   ['Add spinach to boiling water; cook 1 minute....   NaN
# 1367  ['Tear chard leaves from stems, then coarsely ...  26.0
# 1536  ['Preheat oven to 350°F. Spread out pistachios...  19.0
# 472   ['In a large skillet cook leeks in oil over mo...  12.0
# 1658  ['Whisk first 5 ingredients in large bowl. Sea...   NaN
# 1800  ["Heat 4 cups canola oil in a 2-quart pot to 3...  69.0
# 1398  ["Scrub (but don't peel) the yams, cut them in...   6.0
# 1212  ['Cut off and discard top third of tomatoes an...  18.0
# 1758  ['Cut off and discard top third of tomatoes an...  18.0
# 565   ['Mince garlic and in a small dry skillet toas...   9.0
# 838   ['Mix cornmeal and 1/4 teaspoon cayenne in sma...  22.0
# ...

# %%
df_vegan_trained
# Out:
#                                              directions   fat  \
# 50    ['Rinse the spinach well and remove the stems....  10.0
# 1756  ['Place colander over large bowl. Line colande...  11.0
# 522   ['Add spinach to boiling water; cook 1 minute....   NaN
# 912   ['Add spinach to boiling water; cook 1 minute....   NaN
# 1367  ['Tear chard leaves from stems, then coarsely ...  26.0
# ...                                                 ...   ...
# 1777  ['Preheat oven to 250°F. Lightly oil a large s...   5.0
# 1213  ['Preheat oven to 250°F. Lightly oil a large s...   5.0
# 413   ['Bring broth to boil in large saucepan over m...  26.0
# 1357  ['Soak chiles in a bowl of very hot water unti...   7.0
# 1732  ['Roast peppers in a 450°F oven for 20-25 minu...   2.0
#
#                                              categories  calories  \
# 50    ['Side', 'Sauté', 'Vegetarian', 'Rosh Hashanah...     159.0
# 1756  ['Fruit', 'Leafy Green', 'Olive', 'Side', 'Han...     142.0
# ...

# %%
df_vegan_trained_cleaned = df_vegan_trained.dropna()
df_vegan_trained_cleaned = df_vegan_trained_cleaned.drop_duplicates(subset = ['title'])

# %%
df_vegan_trained_cleaned = df_vegan_trained_cleaned.reset_index()
df_vegan_trained_cleaned = df_vegan_trained_cleaned.drop(columns='index')
df_vegan_trained_cleaned
# Out:
#                                             directions   fat  \
# 0    ['Rinse the spinach well and remove the stems....  10.0
# 1    ['Preheat oven to 350°F. Spread out pistachios...  19.0
# 2    ['In a large skillet cook leeks in oil over mo...  12.0
# 3    ["Heat 4 cups canola oil in a 2-quart pot to 3...  69.0
# 4    ["Scrub (but don't peel) the yams, cut them in...   6.0
# ..                                                 ...   ...
# 896  ['Cook fava beans in large saucepan of boiling...  12.0
# 897  ['Combine the vinegar, mustard, and salt. Whis...  14.0
# 898  ['Pulse first 8 ingredients in a food processo...  44.0
# 899  ['Bring broth to boil in large saucepan over m...  26.0
# 900  ['Soak chiles in a bowl of very hot water unti...   7.0
#
#                                             categories  calories  \
# 0    ['Side', 'Sauté', 'Vegetarian', 'Rosh Hashanah...     159.0
# 1    ['Salad', 'Side', 'Raisin', 'Pistachio', 'Root...     319.0
# ...

# %%
query_text = preprocess_text(sentences)
query_encoding = embedding_model_vegan(tf.constant([query_text]))

df_vegan_trained_cleaned['similarity_score'] = df_vegan_trained_cleaned['encoding'].apply(lambda x: metrics.pairwise.cosine_similarity(x, query_encoding)[0][0])
df_vegan_trained_cleaned = df_vegan_trained_cleaned.sort_values(by=['similarity_score'], ascending=False)
df_vegan_trained_cleaned
# Out:
#                                             directions   fat  \
# 0    ['Rinse the spinach well and remove the stems....  10.0
# 1    ['Preheat oven to 350°F. Spread out pistachios...  19.0
# 2    ['In a large skillet cook leeks in oil over mo...  12.0
# 3    ["Heat 4 cups canola oil in a 2-quart pot to 3...  69.0
# 4    ["Scrub (but don't peel) the yams, cut them in...   6.0
# ..                                                 ...   ...
# 896  ['Cook fava beans in large saucepan of boiling...  12.0
# 897  ['Combine the vinegar, mustard, and salt. Whis...  14.0
# 898  ['Pulse first 8 ingredients in a food processo...  44.0
# 899  ['Bring broth to boil in large saucepan over m...  26.0
# 900  ['Soak chiles in a bowl of very hot water unti...   7.0
#
#                                             categories  calories  \
# 0    ['Side', 'Sauté', 'Vegetarian', 'Rosh Hashanah...     159.0
# 1    ['Salad', 'Side', 'Raisin', 'Pistachio', 'Root...     319.0
# ...
